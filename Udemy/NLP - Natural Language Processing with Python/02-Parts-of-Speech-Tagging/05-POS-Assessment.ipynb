# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Parts of Speech Assessment

# %% [markdown]
# For this assessment we'll be using the short story [The Tale of Peter Rabbit](https://en.wikipedia.org/wiki/The_Tale_of_Peter_Rabbit) by Beatrix Potter (1902). <br>The story is in the public domain; the text file was obtained from [Project Gutenberg](https://www.gutenberg.org/ebooks/14838.txt.utf-8).

# %%
# RUN THIS CELL to perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')

from spacy import displacy

# %%
import os
data_folder = os.path.abspath(os.getcwd()).replace("\\", "/") + "/"

# %% [markdown]
# **1. Create a Doc object from the file `peterrabbit.txt`**<br>
# > HINT: Use `with open('../TextFiles/peterrabbit.txt') as f:`

# %%
with open(data_folder + 'peterrabbit.txt') as f:
    doc = nlp(f.read())

# %% [markdown]
# **2. For every token in the third sentence, print the token text, the POS tag, the fine-grained TAG tag, and the description of the fine-grained tag.**

# %%
# Enter your code here:
for token in list(doc.sents)[3]: # é a 4a
    print(f'{token.text:{12}} {token.pos_:{8}} {token.tag_:{8}} {spacy.explain(token.tag_)}')
# Out:
# They         PRON     PRP      pronoun, personal
# lived        VERB     VBD      verb, past tense
# with         ADP      IN       conjunction, subordinating or preposition
# their        DET      PRP$     pronoun, possessive
# Mother       PROPN    NNP      noun, proper singular
# in           ADP      IN       conjunction, subordinating or preposition
# a            DET      DT       determiner
# sand         NOUN     NN       noun, singular or mass
# -            PUNCT    HYPH     punctuation mark, hyphen
# bank         NOUN     NN       noun, singular or mass
# ,            PUNCT    ,        punctuation mark, comma
# underneath   ADP      IN       conjunction, subordinating or preposition
# the          DET      DT       determiner
# root         NOUN     NN       noun, singular or mass
# of           ADP      IN       conjunction, subordinating or preposition
# a            DET      DT       determiner
#
#             SPACE    _SP      None
# very         ADV      RB       adverb
# big          ADJ      JJ       adjective
# fir          NOUN     NN       noun, singular or mass
# -            PUNCT    HYPH     punctuation mark, hyphen
# tree         NOUN     NN       noun, singular or mass
# .            PUNCT    .        punctuation mark, sentence closer
#
#
#            SPACE    _SP      None

# %% [markdown]
# **3. Provide a frequency list of POS tags from the entire document**

# %%
POS_counts = doc.count_by(spacy.attrs.POS)

sorted_POS_counts = sorted(POS_counts.items(), key=lambda x: x[1], reverse=True)
print(sorted_POS_counts, "\n")

for pos, count in sorted_POS_counts:
    print(f"{pos:{6}}. {doc.vocab[pos].text:{5}} : {count:{4}}")
# Out:
# [(97, 174), (92, 171), (100, 136), (85, 123), (90, 118), (103, 99), (95, 81), (96, 73), (86, 67), (89, 61), (84, 50), (87, 48), (94, 29), (98, 20), (93, 8)]
#
#     97. PUNCT :  174
#     92. NOUN  :  171
#    100. VERB  :  136
#     85. ADP   :  123
#     90. DET   :  118
#    103. SPACE :   99
#     95. PRON  :   81
#     96. PROPN :   73
#     86. ADV   :   67
#     89. CCONJ :   61
#     84. ADJ   :   50
#     87. AUX   :   48
#     94. PART  :   29
#     98. SCONJ :   20
#     93. NUM   :    8

# %% [markdown]
# **4. CHALLENGE: What percentage of tokens are nouns?**<br>
# HINT: the attribute ID for 'NOUN' is 91

# %%
print(f'{POS_counts[92]/len(doc)*100: {0.3}}%')
# Out:
#  13.6%

# %% [markdown]
# **5. Display the Dependency Parse for the third sentence**

# %%
from spacy import displacy

# Render the dependency parse immediately inside Jupyter:
displacy.render(list(doc.sents)[3], style='dep', jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="66abf394c109486898699aa3e29d0b01-0" class="displacy" width="2250" height="522.0" direction="ltr" style="max-width: none; height: 522.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">They</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">lived</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">Mother</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">sand-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">bank,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">underneath</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">root</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">big</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">fir-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">tree.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66abf394c109486898699aa3e29d0b01-0-0" stroke-width="2px" d="M70,387.0 C70,332.0 130.0,332.0 130.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66abf394c109486898699aa3e29d0b01-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,389.0 L62,377.0 78,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66abf394c109486898699aa3e29d0b01-0-1" stroke-width="2px" d="M180,387.0 C180,332.0 240.0,332.0 240.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66abf394c109486898699aa3e29d0b01-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M240.0,389.0 L248.0,377.0 232.0,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66abf394c109486898699aa3e29d0b01-0-2" stroke-width="2px" d="M400,387.0 C400,332.0 460.0,332.0 460.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66abf394c109486898699aa3e29d0b01-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,389.0 L392,377.0 408,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66abf394c109486898699aa3e29d0b01-0-3" stroke-width="2px" d="M290,387.0 C290,277.0 465.0,277.0 465.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66abf394c109486898699aa3e29d0b01-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M465.0,389.0 L473.0,377.0 457.0,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66abf394c109486898699aa3e29d0b01-0-4" stroke-width="2px" d="M180,387.0 C180,167.0 585.0,167.0 585.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66abf394c109486898699aa3e29d0b01-0-4" class="displacy-label" startOffset="50%" side="left" f

# %% [markdown]
# **6. Show the first two named entities from Beatrix Potter's *The Tale of Peter Rabbit* **

# %%
for ent in doc.ents[:2]:
    print(ent.text + ' - ' + ent.label_ + ' - ' + str(spacy.explain(ent.label_)))
# Out:
# Peter Rabbit - PERSON - People, including fictional
# Beatrix Potter - PERSON - People, including fictional

# %% [markdown]
# **7. How many sentences are contained in *The Tale of Peter Rabbit*?**

# %%
len(list(doc.sents))
# Out:
# 68

# %% [markdown]
# **8. CHALLENGE: How many sentences contain named entities?**

# %%
# %%time
sents_list = [nlp(sent.text) for sent in doc.sents]
ners_list = [doc for doc in sents_list if doc.ents]
len(ners_list)
# Out:
# Wall time: 976 ms
# 40

# %%
# %%time
# or
counting_ners = 0
for sent in doc.sents:
    if nlp(sent.text).ents:
        counting_ners += 1

counting_ners
# Out:
# Wall time: 956 ms
# 40

# %% [markdown]
# **9. CHALLENGE: Display the named entity visualization for `list_of_sents[0]` from the previous problem**

# %%
displacy.render(sents_list[0], style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The Tale of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Rabbit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beatrix Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1902
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ).
#
# </div></span>

# %% [markdown]
# ### Great Job!
