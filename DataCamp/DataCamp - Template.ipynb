# %% [markdown]
# # DataCamp - Data Scientist Career Track (Python)

# %% [markdown]
# ##

# %%
data_folder = "C:/Users/Utilizador/Dropbox/Python/ficheiros/DataCamp/

# %% [markdown]
# ##    CHAPTER 1  -

# %% [markdown]
# Exercício 1

# %% [markdown]
# Exercício 2

# %% [markdown]
# Exercício 3

# %% [markdown]
# Exercício 4

# %% [markdown]
# Exercício 5

# %% [markdown]
# Exercício 6

# %% [markdown]
# Exercício 7

# %% [markdown]
# Exercício 8

# %% [markdown]
# Exercício 9

# %% [markdown]
# Exercício 10

# %% [markdown]
# Exercício 11

# %% [markdown]
# Exercício 12

# %% [markdown]
# Exercício 13

# %% [markdown]
# Exercício 14

# %% [markdown]
# # CHAPTER 2 -

# %% [markdown]
# Exercício 1

# %% [markdown]
# Exercício 2

# %% [markdown]
# Exercício 3

# %% [markdown]
# Exercício 4

# %% [markdown]
# Exercício 5

# %% [markdown]
# Exercício 6

# %% [markdown]
# Exercício 7

# %% [markdown]
# Exercício 8

# %% [markdown]
# Exercício 9

# %% [markdown]
# Exercício 10

# %% [markdown]
# Exercício 11

# %% [markdown]
# Exercício 12

# %% [markdown]
# Exercício 13

# %% [markdown]
# Exercício 14

# %% [markdown]
# Exercício 15

# %% [markdown]
# # Chapter 3 -

# %% [markdown]
# Exercício 1

# %% [markdown]
# Exercício 2

# %% [markdown]
# Exercício 3

# %% [markdown]
# Exercício 4

# %% [markdown]
# Exercício 5

# %% [markdown]
# Exercício 6

# %% [markdown]
# Exercício 7

# %% [markdown]
# Exercício 8

# %% [markdown]
# Exercício 9

# %% [markdown]
# Exercício 10

# %% [markdown]
# Exercício 11

# %% [markdown]
# Exercício 12

# %% [markdown]
# Exercício 13

# %% [markdown]
# Exercício 14

# %% [markdown]
# Exercício 15

# %% [markdown]
# Exercício 16

# %% [markdown]
# Exercício 17

# %% [markdown]
# # Chapter 4 -

# %% [markdown]
# Exercício 1

# %% [markdown]
# Exercício 2

# %% [markdown]
# Exercício 3

# %% [markdown]
# Exercício 4

# %% [markdown]
# Exercício 5

# %% [markdown]
# Exercício 6

# %% [markdown]
# Exercício 7

# %% [markdown]
# Exercício 8

# %% [markdown]
# Exercício 9

# %% [markdown]
# Exercício 10

# %% [markdown]
# Exercício 11

# %% [markdown]
# Exercício 12

# %% [markdown]
# Exercício 13

# %% [markdown]
# Exercício 14

# %% [markdown]
# Exercício 15

# %% [markdown]
# Exercício 16

# %% [markdown]
# # Fim
