# %% [markdown]
# # Data Visualization with Seaborn (Python)

# %%
data_folder = "C:/Users/Admin/Dropbox/Python/ficheiros/DataCamp/DataCamp - Data Visualization with Seaborn/"

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# plot 1 image
def plot_1(image1, left=0, bottom=0, right=1, top=1, wspace=0, hspace=0, format_img=".jpg"):
    image = plt.imread(data_folder + (image1+format_img))
    plt.axis('off')
    plt.imshow(image)
    plt.subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace)
    plt.show()

# plot 2 images horizontally
def plot_2(image1, image2, left=0, bottom=0, right=2.2, top=1, wspace=0, hspace=0.05, format_img=".jpg"):
    plt.subplot(1, 2, 1)
    image = plt.imread(data_folder + (image1+format_img))
    plt.axis('off')
    plt.imshow(image)
    plt.subplot(1, 2, 2)
    image = plt.imread(data_folder + (image2+format_img))
    plt.axis('off')
    plt.imshow(image)
    plt.subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace)
    plt.show()

# plot 3 images horizontally
def plot_3(image1, image2, image3, left=0, bottom=-1, right=2.7, top=1, wspace=0, hspace=0.1, format_img=".jpg"):
    plt.subplot(1, 3, 1)
    imagem = plt.imread(data_folder + (image1+format_img))
    plt.axis('off')
    plt.imshow(imagem)
    plt.subplot(1, 3, 2)
    imagem = plt.imread(data_folder + (image2+format_img))
    plt.axis('off')
    plt.imshow(imagem)
    plt.subplot(1, 3, 3)
    imagem = plt.imread(data_folder + (image3+format_img))
    plt.axis('off')
    plt.imshow(imagem)
    plt.subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace)
    plt.show()
    
# plot 4 images horizontally
def plot_4(image1, image2, image3, image4, left=0, bottom=-1, right=2.7, top=1, wspace=0, hspace=0.1, format_img=".jpg"):
    plt.subplot(1, 4, 1)
    imagem = plt.imread(data_folder + (image1+format_img))
    plt.axis('off')
    plt.imshow(imagem)
    plt.subplot(1, 4, 2)
    imagem = plt.imread(data_folder + (image2+format_img))
    plt.axis('off')
    plt.imshow(imagem)
    plt.subplot(1, 4, 3)
    imagem = plt.imread(data_folder + (image3+format_img))
    plt.axis('off')
    plt.imshow(imagem)
    plt.subplot(1, 4, 4)
    imagem = plt.imread(data_folder + (image4+format_img))
    plt.axis('off')
    plt.imshow(imagem)    
    plt.subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace)
    plt.show()

# %% [markdown]
# ##    CHAPTER 1  - Seaborn Introduction

# %% [markdown]
# #### Exercício 1 - Introduction to Seaborn

# %%
#vídeo

plot_1('python_visualization', right=2)
# Seaborn is built on matplotlib and works best with pandas' dataframes

# %% [markdown]
# Exercício 2

# %%
#Seaborn foundation

# What library provides the foundation for pandas and Seaborn plotting?
print("matplotlib")
# Out:
# matplotlib

# %% [markdown]
# Exercício 3

# %%
# Reading a csv file

# Read in the DataFrame
df = pd.read_csv(data_folder + "schoolimprovement2010grants.csv").drop('Unnamed: 0', axis=1)
df.head()
# Out:
#                          School Name      City State  \
# 0  HOGARTH KINGEEKUK MEMORIAL SCHOOL  SAVOONGA    AK
# 1                    AKIACHAK SCHOOL  AKIACHAK    AK
# 2                     GAMBELL SCHOOL   GAMBELL    AK
# 3               BURCHELL HIGH SCHOOL   WASILLA    AK
# 4                       AKIAK SCHOOL     AKIAK    AK
#
#                                District Name  Model Selected  Award_Amount  \
# 0              BERING STRAIT SCHOOL DISTRICT  Transformation        471014
# 1                     YUPIIT SCHOOL DISTRICT  Transformation        520579
# 2              BERING STRAIT SCHOOL DISTRICT  Transformation        449592
# 3  MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT  Transformation        641184
# 4                     YUPIIT SCHOOL DISTRICT  Transformation        399686
#
#   Region
# 0   West
# 1   West
# 2   West
# 3   West
# 4   West

# %% [markdown]
# Exercício 4

# %%
# Comparing a histogram and distplot

# Display pandas histogram
plt.subplot(1, 2, 1)
df['Award_Amount'].plot.hist()

# Clear out the pandas histogram
# plt.clf()

# Display a Seaborn distplot
plt.subplot(1, 2, 2)
sns.distplot(df['Award_Amount'])

# Clear the distplot
# plt.clf()

plt.subplots_adjust(left=0, bottom=0, right=2.2, top=1, wspace=0.2, hspace=0.05)
plt.show()

# %% [markdown]
# #### Exercício 5 - Using the distribution plot

# %%
#vídeo

# In order to plot a simple histogram, you can disable the kde and specify the number of bins to use

# Alternative data distributions
#  - A rug plot is an alternative way to view the distribution of data
#  - A kde curve and rug plot can be combined

# %% [markdown]
# Exercício 6

# %%
# Plot a histogram

# Create a distplot
sns.distplot(df['Award_Amount'], kde=False, bins=20)

# Display the plot
plt.show()

# %% [markdown]
# Exercício 7

# %%
# Rug plot and kde shading

# Create a distplot of the Award Amount
sns.distplot(df['Award_Amount'], hist=False, rug=True, kde_kws={'shade':True})

# Plot the results
plt.show()
print("This plot can be really useful for understanding how the award dollars were distributed.")
# Out:
# This plot can be really useful for understanding how the award dollars were distributed.

# %% [markdown]
# Exercício 8

# %%
# Interpreting the results

# Looking at the previous distplot, which of these choices can you infer based on the visualization?
print("""There are a large group of award amounts < $400K.""")
# Out:
# There are a large group of award amounts < $400K.

# %% [markdown]
# #### Exercício 9 - Regression plots in Seaborn

# %%
#vídeo

# %% [markdown]
# Exercício 10

# %%
# Create a regression plot

df = pd.read_csv(data_folder + "insurance_premiums.csv")

# regplot
sns.regplot(data=df, x="insurance_losses", y="premiums")
plt.title('regplot')

# lmplot
sns.lmplot(data=df, x="insurance_losses", y="premiums")
plt.title('lmplot')

plt.show()
df.head()
# Out:
#         State  fatal_collisions  fatal_collisions_speeding  \
# 0     Alabama              18.8                         39
# 1      Alaska              18.1                         41
# 2     Arizona              18.6                         35
# 3    Arkansas              22.4                         18
# 4  California              12.0                         35
#
#    fatal_collisions_alc  fatal_collisions_not_distracted  \
# 0                    30                               96
# 1                    25                               90
# 2                    28                               84
# 3                    26                               94
# 4                    28                               91
#
#    fatal_collisions_no_hist  premiums  insurance_losses Region
# 0                        80    784.55            145.08  South
# 1                        94   1053.48            133.93   West
# 2                        96    899.47            110.35   West
# ...

# %% [markdown]
# Exercício 11

# %%
# Plotting multiple variables

# Create a regression plot using hue
sns.lmplot(data=df, x="insurance_losses", y="premiums", hue="Region", legend_out=False)  # legend_out para não sobrepôr

# Show the results
plt.subplots_adjust(left=0, bottom=0, right=1.2, top=1, wspace=0.2, hspace=0.05)
plt.show()

# %% [markdown]
# Exercício 12

# %%
# Facetting multiple regressions

# Create a regression plot with multiple rows
sns.lmplot(data=df, x="insurance_losses", y="premiums", row="Region")

# Show the plot
plt.show()

# %% [markdown]
# # CHAPTER 2 - Customizing Seaborn Plots

# %% [markdown]
# #### Exercício 1 - Using Seaborn Styles

# %%
# vídeo

df = pd.read_csv(data_folder + "college_datav3.csv").dropna()

# Seaborn has default congurations that can be applied with
sns.set()   # default, also called 'darkgrid'
# These styles can override matplotlib and pandas plots as well

# Theme examples with sns.set_style()
j = 1
for style in ['white', 'dark', 'whitegrid', 'darkgrid', 'ticks']:
    plt.subplot(2, 3, j)
    sns.set_style(style)
    sns.distplot(df['Tuition'])
    plt.title(style, fontsize=15)
    j=j+1

# plt.show()

# Removing axes with despine()
plt.subplot(2, 3, 6)
sns.set_style('white')
sns.distplot(df['Tuition'])
sns.despine(left=True)
plt.title('Removing axes with despine()', fontsize=16)

plt.subplots_adjust(left=0, bottom=-1.5, right=3, top=1, wspace=0.3, hspace=0.2)
plt.show()
sns.set()

# %% [markdown]
# Exercício 2

# %%
# Setting the default style

# market rent values calculated by the US Housing and Urban Development Department
df = pd.read_csv(data_folder + "FY18_4050_FMRs.csv")
sns.set_style("white")

# Plot the pandas histogram
plt.subplot(1, 2, 1)
df['fmr_2'].plot.hist()
plt.title('without seaborn default style', fontsize=15)

# Set the default seaborn style
sns.set()

# Plot the pandas histogram again
plt.subplot(1, 2, 2)
df['fmr_2'].plot.hist()
plt.title('with seaborn default style', fontsize=15)
plt.subplots_adjust(left=0, bottom=0, right=2.2, top=1, wspace=0.2, hspace=0.05)
plt.show()

# %% [markdown]
# Exercício 3

# %%
# Comparing styles

# ver acima - ['white', 'dark', 'whitegrid', 'darkgrid', 'ticks']

# %% [markdown]
# Exercício 4

# %%
# Removing spines

# Set the style to white
sns.set_style('white')

# Create a regression plot
sns.lmplot(data=df, x='pop2010', y='fmr_2')

# Remove the spines
sns.despine()
plt.show()

# %% [markdown]
# #### Exercício 5 - Colors in Seaborn

# %%
# Colors in Seaborn

df = pd.read_csv(data_folder + "college_datav3.csv").dropna()

# Defining a color for a plot
# Seaborn supports assigning colors to plots using matplotlib color codes
print("Define color:")
sns.set(color_codes=True)
sns.distplot(df['Tuition'], color='g')
plt.title('green')
plt.show()

# Palettes
# Seaborn uses the set_palette() function to define a palette
print("Palettes:")
j=1
for p in sns.palettes.SEABORN_PALETTES:
    plt.subplot(4, 3, j)
    sns.set_palette(p)
    sns.distplot(df['Tuition'])
    plt.title(p, fontsize=18)
    plt.xlabel('')
    j=j+1

plt.subplots_adjust(left=0, bottom=-2.7, right=3, top=1, wspace=0.3, hspace=0.3)
plt.show()
# Out:
# Define color:
# Palettes:

# %%
# Displaying Palettes
print("Displaying Palettes:")
for p in sns.palettes.SEABORN_PALETTES:
    sns.set_palette(p)
    sns.palplot(sns.color_palette())
    plt.title(p, fontsize=16)
    plt.show()
# Out:
# Displaying Palettes:

# %%
# Defining Custom Plattes

# - Circular colors = when the data is not ordered
sns.palplot(sns.color_palette("Paired", 12))
plt.title("Paired")
plt.show()

# - Sequential colors = when the data has a consistent range from high to low
sns.palplot(sns.color_palette("Blues", 12))
plt.title("Blues")
plt.show()

# - Diverging colors = when both the low and high values are interesting
sns.palplot(sns.color_palette("BrBG", 12))
plt.title("BrBG")
plt.show()

# %% [markdown]
# Exercício 6

# %%
# Matplotlib color codes

df = pd.read_csv(data_folder + "FY18_4050_FMRs.csv")

# Set style, enable color code, and create a magenta distplot
sns.set(color_codes=True)
sns.distplot(df['fmr_3'], color='m')
plt.title("magenta ('m')")
plt.show()

# %% [markdown]
# Exercício 7

# %%
# Using default palettes

# Loop through differences between bright and colorblind palettes
j=1
for p in ['bright', 'colorblind']:
    plt.subplot(1, 2, j)
    sns.set_palette(p)
    sns.distplot(df['fmr_3'])
    plt.title(p, fontsize=16)
    j=j+1
plt.subplots_adjust(left=0, bottom=0, right=2, top=1, wspace=0.3, hspace=0.3)
plt.show()

# %% [markdown]
# Exercício 8

# %%
# Color Palettes

# When visualizing multiple elements of data that do not have inherent ordering. 
# Which type of Seaborn palette should you use?
print("circular")
# Out:
# circular

# %% [markdown]
# Exercício 9

# %%
# Creating Custom Palettes

# Create and display a Purples sequential palette containing 8 colors. 
sns.palplot(sns.color_palette("Purples", 8))
plt.title("Purples")
plt.show()

# Create and display a palette with 10 colors using the husl system.
sns.palplot(sns.color_palette("husl", 10))
plt.title("husl")
plt.show()

# Create and display a diverging palette with 6 colors coolwarm.
sns.palplot(sns.color_palette("coolwarm", 6))
plt.title("coolwarm")
plt.show()

# %% [markdown]
# #### Exercício 10 - Customizing with matplotlib

# %%
# vídeo

df = pd.read_csv(data_folder + "college_datav3.csv").dropna()

# Matplotlib Axes
fig, ax = plt.subplots()
sns.distplot(df['Tuition'], ax=ax)
ax.set(xlabel="Tuition 2013-14")

# Further Customizations
# The axes object supports many common customizations
fig, ax = plt.subplots()
sns.distplot(df['Tuition'], ax=ax)
ax.set(xlabel="Tuition 2013-14", ylabel="Distribution", xlim=(0, 50000), title="2013-14 Tuition and Fees Distribution")

# Combining Plots
# It is possible to combine and congure multiple plots
fig, (ax0, ax1) = plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(15,4))
sns.distplot(df['Tuition'], ax=ax0)
sns.distplot(df.query("Regions == 'South East'")['Tuition'], ax=ax1)

ax1.set(xlabel="Tuition (South East)", xlim=(0, 70000))
ax1.axvline(x=20000, label='My Budget', linestyle='--')
ax1.legend()
# plt.subplots_adjust(left=0, bottom=0, right=2, top=1, wspace=0.3, hspace=0.3)
plt.show()

# %% [markdown]
# Exercício 11

# %%
df = pd.read_csv(data_folder + "FY18_4050_FMRs.csv")

# %%
# Using matplotlib axes

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the distribution of data
sns.distplot(df['fmr_3'], ax=ax)

# Create a more descriptive x axis label
ax.set(xlabel="3 Bedroom Fair Market Rent")

# Show the plot
plt.show()

# %% [markdown]
# Exercício 12

# %%
# Additional plot customizations

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the distribution of 1 bedroom rents
sns.distplot(df['fmr_1'], ax=ax)

# Modify the properties of the plot
ax.set(xlabel="1 Bedroom Fair Market Rent", xlim=(100, 1500), title="US Rent")
plt.show()

# %% [markdown]
# Exercício 13

# %%
# Adding annotations

# Create a figure and axes. Then plot the data
fig, ax = plt.subplots()
sns.distplot(df['fmr_1'], ax=ax)

# Customize the labels and limits
ax.set(xlabel="1 Bedroom Fair Market Rent", xlim=(100,1500), title="US Rent")

# Add vertical lines for the median and mean
ax.axvline(x=np.median(df['fmr_1']), color='m', label='Median', linestyle='--', linewidth=2)
ax.axvline(x=np.mean(df['fmr_1']), color='b', label='Mean', linestyle='-', linewidth=2)

# Show the legend and plot the data
ax.legend()

plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0.3, hspace=0.3)
plt.show()

# %% [markdown]
# Exercício 14

# %%
# Multiple plots

# Create a plot with 1 row and 2 columns that share the y axis label
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharey=True)

# Plot the distribution of 1 bedroom apartments on ax0
sns.distplot(df['fmr_1'], ax=ax0)
ax0.set(xlabel="1 Bedroom Fair Market Rent", xlim=(100,1500), title='sharey')

# Plot the distribution of 2 bedroom apartments on ax1
sns.distplot(df['fmr_2'], ax=ax1)
ax1.set(xlabel="2 Bedroom Fair Market Rent", xlim=(100,1500), title='sharey')

plt.subplots_adjust(left=0, bottom=0, right=1.5, top=1, wspace=0.3, hspace=0.3)
plt.show()

# %% [markdown]
# # Chapter 3 - Additional Plot Types

# %% [markdown]
# #### Exercício 1 - Categorical plot types

# %%
#vídeo
df = pd.read_csv(data_folder + "FY18_4050_FMRs.csv")

print("""Categorical plots are divided into 3 groups, in Seaborn:

 - 1) Show all individual observations (stripplot and swarmplot)
 - 2) Abstract representations (boxplot, violinplot, lvplot)
 - 3) Statistical estimates (barplot, pointplot, countplot)""")

plot_3('all_observ', 'abstract', 'statistical')
print("""stripplot --> use jitter=True for better visualization
lvplot --> nice. mix between boxplot and violinplot""")
# Out:
# Categorical plots are divided into 3 groups, in Seaborn:
#
#  - 1) Show all individual observations (stripplot and swarmplot)
#  - 2) Abstract representations (boxplot, violinplot, lvplot)
#  - 3) Statistical estimates (barplot, pointplot, countplot)
# stripplot --> use jitter=True for better visualization
# lvplot --> nice. mix between boxplot and violinplot

# %% [markdown]
# Exercício 2

# %%
# stripplot() and swarmplot()

print("ALL INDIVIDUAL OBSERVATIONS TYPE OF SEABORN PLOTS:")

df = pd.read_csv(data_folder + "schoolimprovement2010grants.csv").drop('Unnamed: 0', axis=1)

# Create the stripplot
plt.subplot(1, 2, 1)
sns.stripplot(data=df, x='Award_Amount', y='Model Selected', jitter=True)
plt.title('stripplot', fontsize=15)

plt.subplots_adjust(left=0, bottom=0, right=2, top=1, wspace=0.3, hspace=0.3)
plt.show()

# Create and display a swarmplot with hue set to the Region
plt.subplot(1, 2, 2)
sns.swarmplot(data=df, x='Award_Amount', y='Model Selected', hue='Region')
plt.title('swarmplot, by region', fontsize=15)
plt.legend(bbox_to_anchor=(1, 1))

plt.subplots_adjust(left=0, bottom=0, right=2, top=1, wspace=0.3, hspace=0.3)
plt.show()
# Out:
# ALL INDIVIDUAL OBSERVATIONS TYPE OF SEABORN PLOTS:

# %% [markdown]
# Exercício 3

# %%
# boxplots, violinplots and lvplots

from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')

print("ABSTRACT TYPE PLOTS:")

# Create a boxplot
plt.subplot(1, 2, 1)
sns.boxplot(data=df, x='Award_Amount', y='Model Selected')
plt.title('boxplot', fontsize=15)

# Create a violinplot with the husl palette
plt.subplot(1, 2, 2)
sns.violinplot(data=df, x='Award_Amount', y='Model Selected', palette='husl')
plt.title('violinplot', fontsize=15)
plt.subplots_adjust(left=0, bottom=0, right=2, top=1, wspace=0.3, hspace=0.3)
plt.show()

# Create a lvplot with the Paired palette and the Region column as the hue
print("\nThe 'lvplot' function has been renamed to 'boxenplot':")
sns.boxenplot(data=df, x='Award_Amount', y='Model Selected', palette='Paired', hue='Region')
plt.title('lvplot / boxenplot', fontsize=15)
plt.legend(bbox_to_anchor=(1, 1))
plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0.3, hspace=0.3)
plt.show()
# Out:
# ABSTRACT TYPE PLOTS:
# The 'lvplot' function has been renamed to 'boxenplot':

# %% [markdown]
# Exercício 4

# %%
# barplots, pointplots and countplots

print("STATISTICAL ESTIMATES PLOTS:")

# Show a countplot with the number of models used with each region a different color
plt.subplot(1, 2, 1)
sns.countplot(data=df, y="Model Selected", hue="Region")
plt.title('countplot', fontsize=18)

# Create a pointplot and include the capsize in order to show bars on the confidence interval
plt.subplot(1, 2, 2)
sns.pointplot(data=df, y='Model Selected', x='Award_Amount', capsize=.1)
plt.title('pointplot', fontsize=18)
plt.subplots_adjust(left=0, bottom=-0.5, right=3, top=1, wspace=0.3, hspace=0.3)
plt.show()

# Create a barplot with each Region shown as a different color
sns.barplot(data=df, y='Award_Amount', x='Model Selected', hue='Region')
plt.title('barplot', fontsize=18)
plt.subplots_adjust(left=0, bottom=0, right=0.9, top=1, wspace=0.3, hspace=0.3)
plt.show()
# Out:
# STATISTICAL ESTIMATES PLOTS:

# %% [markdown]
# #### Exercício 5 - Regression plots

# %%
#vídeo

df = pd.read_csv(data_folder + "bike_share.csv")

# %% [markdown]
# Exercício 6

# %%
# Regression and residual plots

# US Department of Education on 4 year college tuition information 
df = pd.read_csv(data_folder + "college_datav3.csv").dropna()

# Display a regression plot for Tuition
plt.subplot(1, 2, 1)
sns.regplot(data=df, y='Tuition', x="SAT_AVG_ALL", marker='^', color='g')
plt.title('regression plot')

# Display the residual plot
plt.subplot(1, 2, 2)
sns.residplot(data=df, y='Tuition', x="SAT_AVG_ALL", color='g')
plt.title('residual plot')

plt.subplots_adjust(left=0, bottom=0, right=2, top=1, wspace=0.3, hspace=0.3)
plt.show()
print("There does appear to be a linear relationship between tuition and SAT scores.")
# Out:
# There does appear to be a linear relationship between tuition and SAT scores.

# %% [markdown]
# Exercício 7

# %%
# Regression plot parameters

# Plot a regression plot of Tuition and the Percentage of Pell Grants
plt.subplot(1, 3, 1)
sns.regplot(data=df, y='Tuition', x="PCTPELL")
plt.title('regression plot', fontsize=17)

# Create another plot that estimates the tuition by PCTPELL
plt.subplot(1, 3, 2)
sns.regplot(data=df, y='Tuition', x="PCTPELL", x_bins=5)
plt.title('regression plot with 5 bins', fontsize=17)

# The final plot should include a line using a 2nd order polynomial
plt.subplot(1, 3, 3)
sns.regplot(data=df, y='Tuition', x="PCTPELL", x_bins=5, order=2)
plt.title('regression plot - 2nd order polynomial', fontsize=17)
plt.subplots_adjust(left=0, bottom=0, right=3, top=1, wspace=0.3, hspace=0.3)
plt.show()

# %% [markdown]
# Exercício 8

# %%
# Binning data

# Create a scatter plot by disabling the regression line
plt.subplot(1, 3, 1)
sns.regplot(data=df, y='Tuition', x="UG", fit_reg=False)
plt.title("regression plot \n disabling the regression line", fontsize=17)

# Create a scatter plot and bin the data into 5 bins
plt.subplot(1, 3, 2)
sns.regplot(data=df, y='Tuition', x="UG", x_bins=5)
plt.title("regression plot \n 5 bins", fontsize=17)

# Create a regplot and bin the data into 9 bins
plt.subplot(1, 3, 3)
sns.regplot(data=df, y='Tuition', x="UG", x_bins=9)
plt.title("regression plot \n 9 bins", fontsize=17)

plt.subplots_adjust(left=0, bottom=0, right=3, top=1, wspace=0.3, hspace=0.3)
plt.show()

# %% [markdown]
# #### Exercício 9 - Matrix plots

# %%
#vídeo
df = pd.read_csv(data_folder + "bike_share.csv")

# Getting data in the rightformat
# - Seaborn's heatmap() function requires data to be in a grid format
# - pandas crosstab() is frequently used to manipulate the data 
df_crosstab = pd.crosstab(df["mnth"], df["weekday"], values=df["total_rentals"],aggfunc='mean').round(0)
print(df_crosstab)

# Build a heatmap
plt.subplot(1, 2, 1)
sns.heatmap(df_crosstab)
plt.title('heatmap')

# Customize a heatmap
df_crosstab = df_crosstab.astype(int)
plt.subplot(1, 2, 2)
sns.heatmap(df_crosstab, annot=True, cmap="YlGnBu", cbar=False, linewidths=.5)
plt.title('heatmap customized')
plt.subplots_adjust(left=0, bottom=0, right=2, top=1, wspace=0.3, hspace=0.3)
plt.show()

# Centering a heatmap
# - Seaborn support centering the heatmap colors on a specic value
plt.subplot(1, 2, 1)
sns.heatmap(df_crosstab, annot=True, fmt="d", cmap="YlGnBu", cbar=True, center=df_crosstab.loc[9, 6])
plt.title('centering the heatmap around a specific value (6394)')

# Plotting a correlation matrix
# - Pandas corr function calculates correlations between columns in a dataframe
# - The output can be converted to a heatmap with seaborn
plt.subplot(1, 2, 2)
sns.heatmap(df.corr())
plt.title('correlation matrix')
plt.subplots_adjust(left=0, bottom=0, right=2, top=1, wspace=0.3, hspace=0.3)
plt.show()
# Out:
# weekday       0       1       2       3       4       5       6
# mnth
# 1        1816.0  1927.0  2568.0  2139.0  2513.0  2446.0  1957.0
# 2        2248.0  2604.0  2824.0  2813.0  2878.0  2933.0  2266.0
# 3        3301.0  3546.0  3574.0  3670.0  3817.0  3926.0  3939.0
# 4        4417.0  4516.0  4556.0  4331.0  4764.0  4387.0  4446.0
# 5        5320.0  4512.0  5025.0  5119.0  5893.0  5751.0  5978.0
# 6        5940.0  5478.0  5681.0  5701.0  5622.0  5616.0  6344.0
# 7        5298.0  5792.0  5844.0  5814.0  5624.0  5406.0  5232.0
# 8        4703.0  5518.0  5930.0  6077.0  6038.0  5958.0  5224.0
# 9        6160.0  5637.0  5184.0  5668.0  5486.0  5747.0  6394.0
# 10       4735.0  4632.0  5065.0  5505.0  5537.0  5623.0  5445.0
# 11       4126.0  4658.0  4040.0  4136.0  3994.0  4524.0  4288.0
# 12       2740.0  3498.0  3713.0  3270.0  3711.0  3742.0  3195.0

# %% [markdown]
# Exercício 10

# %%
# Creating heatmaps

df = pd.read_csv(data_folder + "daily_show_guests_cleaned.csv")
print("Daily show guests:")

# Create a crosstab table of the data
pd_crosstab = pd.crosstab(df["Group"], df["YEAR"])

# Plot a heatmap of the table
sns.heatmap(pd_crosstab)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.subplots_adjust(left=0, bottom=-0.5, right=1.5, top=1, wspace=0.3, hspace=0.3)
plt.show()
pd_crosstab
# Out:
# Daily show guests:
# YEAR            1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  \
# Group
# Academic           0     0     2     0     4     1    12     9    13     5
# Acting           108   100    92    84    74    51    44    44    25    26
# Advocacy           0     1     0     1     0     4     0     0     2     3
# Athletics          0     3     1     2     0     2     2     5     4     1
# Business           0     1     0     0     0     2     1     1     2     1
# Clergy             0     0     0     1     1     1     0     0     1     0
# Comedy            25    12    11     5    12     7     5     8     9     7
# Consultant         0     0     0     0     1     4     1     4     2     3
# Government         0     0     2     1     2     3     1     3     1     0
# Media             11    21    31    42    41    45    54    47    47    77
# Military           0     0     0     0     0     0     1     1     3     1
# ...

# %% [markdown]
# Exercício 11

# %%
# Customizing heatmaps

# Plot a heatmap of the table with no color bar and using the BuGn palette
sns.heatmap(pd_crosstab, cbar=False, cmap="BuGn", linewidths=0.3)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.subplots_adjust(left=0, bottom=-0.5, right=1.5, top=1, wspace=0.3, hspace=0.3)
plt.show()

# %% [markdown]
# # Chapter 4 - Creating Plots on Data Aware Grids

# %% [markdown]
# #### Exercício 1 - Using FacetGrid, factorplot and Implot

# %%
#vídeo

df = pd.read_csv(data_folder + "college_datav3.csv").dropna()

# FacetGrid
# - The FacetGrid is foundational for many data aware grids
# - It allows the user to control how data is distributed across columns, rows and hue
# - Once a FacetGrid is created, the plot type must be mapped to the grid

# FacetGrid Categorical Example
print("FacetGrid Categorical Example:")
g = sns.FacetGrid(df, col="HIGHDEG")
g.map(sns.boxplot, 'Tuition', order=['1', '2', '3', '4'])
plt.show()

# factorplot() --> renamed to catplot()
print("catplot(): simpler way to use a FacetGrid for categorical data")
# - The factorplot is a simpler way to use a FacetGrid for categorical data
# - Combines the facetting and mapping process into 1 function
sns.catplot(x="Tuition", data=df, col="HIGHDEG", kind='box')
plt.show()

# FacetGrid for regression
print("FacetGrid for regression:")
g = sns.FacetGrid(df, col="HIGHDEG")
g.map(plt.scatter,'Tuition','SAT_AVG_ALL')
plt.show()

# lmplot
print("lmplot: plots scatter and regression plots on a FacetGrid")
sns.lmplot(data=df, x="Tuition", y="SAT_AVG_ALL", col="HIGHDEG", fit_reg=True)
plt.show()
# Out:
# FacetGrid Categorical Example:
# catplot(): simpler way to use a FacetGrid for categorical data
# FacetGrid for regression:
# lmplot: plots scatter and regression plots on a FacetGrid

# %% [markdown]
# Exercício 2

# %%
# Building a FacetGrid

df = pd.read_csv(data_folder + "college_datav3.csv").dropna()

# Create FacetGrid with Degree_Type and specify the order of the rows using row_order (usei com colunas para ficar melhor)
g2 = sns.FacetGrid(df, col="Degree_Type", col_order=['Graduate', 'Bachelors', 'Associates', 'Certificate'])

# Map a pointplot of SAT_AVG_ALL onto the grid
g2.map(sns.pointplot, 'SAT_AVG_ALL')
plt.show()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:715: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# Exercício 3

# %%
# Using a catplot

# Create a factor plot that contains boxplots of Tuition values
sns.catplot(data=df, x='Tuition', kind='box', col='Degree_Type')
plt.show()

# Create a facetted pointplot of Average SAT_AVG_ALL scores facetted by Degree Type 
sns.catplot(data=df, x='SAT_AVG_ALL', kind='point', col='Degree_Type',
            col_order=['Graduate', 'Bachelors', 'Associates', 'Certificate'])

plt.show()

# %% [markdown]
# Exercício 4

# %%
# Using a lmplot

degree_ord = ['Graduate', 'Bachelors', 'Associates']

# Create a FacetGrid varying by column and columns ordered with the degree_order variable
g = sns.FacetGrid(df, col="Degree_Type", col_order=degree_ord)

# Map a scatter plot of Undergrad Population compared to PCTPELL
g.map(plt.scatter, 'UG', 'PCTPELL')
plt.subplots_adjust(left=0, bottom=-0.5, right=2, top=1, wspace=0.1, hspace=0.3)
plt.show()

############################################

# Re-create the plot above as an lmplot
sns.lmplot(data=df, x='UG', y='PCTPELL', col="Degree_Type", col_order=degree_ord)
plt.subplots_adjust(left=0, bottom=-0.5, right=2, top=1, wspace=0.1, hspace=0.3)
plt.show()

# %%
inst_ord = ['Public', 'Private non-profit']

# Create an lmplot that has a column for Ownership, a row for Degree_Type and hue based on the WOMENONLY column
sns.lmplot(data=df, x='SAT_AVG_ALL', y='Tuition', col="Ownership", row='Degree_Type',
           row_order=['Graduate', 'Bachelors'], hue='WOMENONLY', col_order=inst_ord)

plt.subplots_adjust(left=0, bottom=-0.5, right=2, top=1, wspace=0.1, hspace=0.3)
plt.show()

# %% [markdown]
# #### Exercício 5 - Using PairGrid and pairplot

# %%
#vídeo

# %% [markdown]
# Exercício 6

# %%
# Building a PairGrid

df = pd.read_csv(data_folder + "insurance_premiums.csv")

# Create a PairGrid with a scatter plot for fatal_collisions and premiums
g = sns.PairGrid(df, vars=["fatal_collisions", "premiums"])
g.map(plt.scatter)
plt.show()

print("==========================================================================================================")

# Create the same PairGrid but map a histogram on the diag
g = sns.PairGrid(df, vars=["fatal_collisions", "premiums"])
g2 = g.map_diag(plt.hist)
g2.map_offdiag(plt.scatter)
plt.show()

# %% [markdown]
# Exercício 7

# %%
# Using a pairplot

# Create a pairwise plot of the variables using a scatter plot
sns.pairplot(data=df, vars=["fatal_collisions", "premiums"], kind='scatter')
plt.subplots_adjust(left=0, bottom=0, right=1.2, top=1, wspace=0.1, hspace=0.3)
plt.show()

# Plot the same data but use a different color palette and color code by Region
sns.pairplot(data=df, vars=["fatal_collisions", "premiums"], kind='scatter',
             hue='Region', palette='RdBu', diag_kws={'alpha':.5})

plt.legend(bbox_to_anchor=(1, 1))

plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0.1, hspace=0.3)
plt.show()

# %% [markdown]
# Exercício 8

# %%
# Additional pairplots

# Build a pairplot with different x and y variables
sns.pairplot(data=df, 
             x_vars=["fatal_collisions_speeding", "fatal_collisions_alc"], 
             y_vars=['premiums', 'insurance_losses'],
             kind='scatter',
             hue='Region',
             palette='husl')

plt.subplots_adjust(left=0, bottom=0, right=0.8, top=1, wspace=0.1, hspace=0.3)
plt.show()

# %%
# plot relationships between insurance_losses and premiums
sns.pairplot(data=df,
             vars=["insurance_losses", "premiums"],
             kind='reg',
             palette='BrBG',
             diag_kind = 'kde',
             hue='Region')

plt.subplots_adjust(left=0, bottom=-0.5, right=2, top=1, wspace=0.1, hspace=0.3)
plt.show()

# %% [markdown]
# #### Exercício 9 - Using JointGrid and jointplot

# %%
#vídeo

df = pd.read_csv(data_folder + "college_datav3.csv").dropna()

from scipy import stats

print("JointGrid:")

# Basic JointGrid
g = sns.JointGrid(data=df, x="Tuition", y="ADM_RATE_ALL")
g.plot(sns.regplot, sns.distplot)
plt.show()

# Advanced JointGrid
g = sns.JointGrid(data=df, x="Tuition", y="ADM_RATE_ALL")
g = g.plot_joint(sns.kdeplot)
g = g.plot_marginals(sns.kdeplot, shade=True)
g = g.annotate(stats.pearsonr)
plt.show()
#########################################################################################################
# Out:
# JointGrid:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
print("jointplot: easier to use, but provides less options on customization")

# jointplot()
sns.jointplot(data=df, x="Tuition", y="ADM_RATE_ALL", kind='hex')
plt.show()

# Customizing a jointplot
g = (sns.jointplot(x="Tuition", y="ADM_RATE_ALL", 
                   kind='scatter', 
                   xlim=(0, 25000), 
                   marginal_kws=dict(bins=15, rug=True),  # to control the structure of the histogram
                   data=df.query('UG < 2500 & Ownership == "Public"')).plot_joint(sns.kdeplot)).annotate(stats.pearsonr)

plt.show()
# Out:
# jointplot: easier to use, but provides less options on customization

# %% [markdown]
# Exercício 10

# %%
# Building a JointGrid and jointplot

df = pd.read_csv(data_folder + "bike_share.csv")

sns.set_style("whitegrid")

# Build a JointGrid comparing humidity ("hum") and total_rentals
g = sns.JointGrid(x="hum", y="total_rentals", data=df,xlim=(0.1, 1.0)) 
g.plot(sns.regplot, sns.distplot)
plt.show()

# Create a jointplot similar to the JointGrid 
sns.jointplot(x="hum", y="total_rentals", kind='reg', data=df)
plt.show()

# %% [markdown]
# Exercício 11

# %%
# Jointplots and regression

# Plot temp vs. total_rentals as a regression plot
sns.jointplot(x="temp", y="total_rentals", kind='reg', data=df, order=2, xlim=(0, 1)).annotate(stats.pearsonr)
plt.show()

# Plot a jointplot showing the residuals
sns.jointplot(x="temp", y="total_rentals", kind='resid', data=df, order=2)
plt.show()

print("""Based on the residual plot and the pearson r value, there is a positive relationship between temperature and 
total_rentals.""")
# Out:
# Based on the residual plot and the pearson r value, there is a positive relationship between temperature and
# total_rentals.

# %% [markdown]
# Exercício 12

# %%
# Complex jointplots

# Create a jointplot of temp vs. casual riders
# Include a kdeplot over the scatter plot
g = (sns.jointplot(x="temp", y="casual", kind='scatter', data=df, marginal_kws=dict(bins=12, rug=True))
    .plot_joint(sns.kdeplot)).annotate(stats.pearsonr)
    
plt.show()

# Replicate the above plot but only for registered riders
print("Only for registered riders:")
g = (sns.jointplot(x="temp", y="registered",
             kind='scatter',
             data=df,
             marginal_kws=dict(bins=10, rug=True)).plot_joint(sns.kdeplot)).annotate(stats.pearsonr)

plt.show()
# Out:
# Only for registered riders:

# %% [markdown]
# #### Exercício 13 - Selecting Seaborn plots

# %%
# vídeo

plot_2('univariate', 'regression')
plot_2('categorical', 'pairplot_jointplot')

# %% [markdown]
# # Fim
